# %%
import pandas as pd

df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3']
})

df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7']
})

df3 = pd.DataFrame({
    'A': ['A8', 'A9', 'A10', 'A11'],
    'B': ['B8', 'B9', 'B10', 'B11']
})

# %%
df1
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
plusdf=pd.concat([df1,df2,df3],axis=0, ignore_index=True)

# %%
plusdf
# Out:
#       A    B
# 0    A0   B0
# 1    A1   B1
# 2    A2   B2
# 3    A3   B3
# 4    A4   B4
# 5    A5   B5
# 6    A6   B6
# 7    A7   B7
# 8    A8   B8
# 9    A9   B9
# 10  A10  B10
# 11  A11  B11

# %%
plusdf_vertical=pd.concat([df1,df2,df3],axis=1)

# %%
plusdf_vertical
# Out:
#     A   B   A   B    A    B
# 0  A0  B0  A4  B4   A8   B8
# 1  A1  B1  A5  B5   A9   B9
# 2  A2  B2  A6  B6  A10  B10
# 3  A3  B3  A7  B7  A11  B11

# %%
df1_m = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'age': [25, 30, 35, 40]
})

# DataFrame 2
df2_m = pd.DataFrame({
    'id': [3, 4, 5, 6],
    'city': ['New York', 'Los Angeles', 'Chicago', 'Houston'],
    'salary': [70000, 80000, 90000, 100000]
})

# %%
dfbyMerge=pd.merge(df1_m,df2_m,on='id',how='inner')

# %%
dfbyMerge
# Out:
#    id     name  age         city  salary
# 0   3  Charlie   35     New York   70000
# 1   4    David   40  Los Angeles   80000

# %%
dfbyMerge=pd.merge(df1_m,df2_m,on='id',how='left')

# %%
dfbyMerge
# Out:
#    id     name  age         city   salary
# 0   1    Alice   25          NaN      NaN
# 1   2      Bob   30          NaN      NaN
# 2   3  Charlie   35     New York  70000.0
# 3   4    David   40  Los Angeles  80000.0

# %%
dfbyMerge=pd.merge(df1_m,df2_m,on='id',how='right')

# %%
dfbyMerge
# Out:
#    id     name   age         city  salary
# 0   3  Charlie  35.0     New York   70000
# 1   4    David  40.0  Los Angeles   80000
# 2   5      NaN   NaN      Chicago   90000
# 3   6      NaN   NaN      Houston  100000

# %%
dfbyMerge=pd.merge(df1_m,df2_m,on='id',how='outer')

# %%
dfbyMerge
# Out:
#    id     name   age         city    salary
# 0   1    Alice  25.0          NaN       NaN
# 1   2      Bob  30.0          NaN       NaN
# 2   3  Charlie  35.0     New York   70000.0
# 3   4    David  40.0  Los Angeles   80000.0
# 4   5      NaN   NaN      Chicago   90000.0
# 5   6      NaN   NaN      Houston  100000.0

# %%
data = {
    'Fecha': ['2024-05-01', '2024-05-01', '2024-05-02', '2024-05-02', '2024-05-03', '2024-05-03'],
    'Tienda': ['Tienda A', 'Tienda B', 'Tienda A', 'Tienda B', 'Tienda A', 'Tienda B'],
    'Producto': ['Producto 1', 'Producto 1', 'Producto 2', 'Producto 2', 'Producto 1', 'Producto 1'],
    'Ventas': [100, 150, 200, 250, 120, 180]
}

df_tienda = pd.DataFrame(data)

# %%
df_tienda
# Out:
#         Fecha    Tienda    Producto  Ventas
# 0  2024-05-01  Tienda A  Producto 1     100
# 1  2024-05-01  Tienda B  Producto 1     150
# 2  2024-05-02  Tienda A  Producto 2     200
# 3  2024-05-02  Tienda B  Producto 2     250
# 4  2024-05-03  Tienda A  Producto 1     120
# 5  2024-05-03  Tienda B  Producto 1     180

# %%
pivot_dfTienda = df_tienda.pivot(index='Fecha', columns=['Tienda', 'Producto'], values='Ventas')

# %%
pivot_dfTienda
# Out:
# Tienda       Tienda A   Tienda B   Tienda A   Tienda B
# Producto   Producto 1 Producto 1 Producto 2 Producto 2
# Fecha
# 2024-05-01      100.0      150.0        NaN        NaN
# 2024-05-02        NaN        NaN      200.0      250.0
# 2024-05-03      120.0      180.0        NaN        NaN

# %%
df_wide = pd.DataFrame({
    'id': [1, 2, 3],
    'name': ['Alice', 'Bob', 'Charlie'],
    'math_score': [85, 90, 95],
    'english_score': [88, 92, 94]
     })

# %%
df_wide
# Out:
#    id     name  math_score  english_score
# 0   1    Alice          85             88
# 1   2      Bob          90             92
# 2   3  Charlie          95             94

# %%
df_long = pd.melt(df_wide, id_vars=['id', 'name'], var_name='subject', value_name='score')

# %%
df_long
# Out:
#    id     name        subject  score
# 0   1    Alice     math_score     85
# 1   2      Bob     math_score     90
# 2   3  Charlie     math_score     95
# 3   1    Alice  english_score     88
# 4   2      Bob  english_score     92
# 5   3  Charlie  english_score     94
